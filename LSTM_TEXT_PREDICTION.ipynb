# %% [markdown]
# <a href="https://colab.research.google.com/github/Harika-Mullaguri/Deep-Learning/blob/main/LSTM_TEXT_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Sample text data
text = """
Once upon a time in a land far away, there was a little village surrounded by lush green forests.
The villagers lived in harmony with nature, cherishing the beauty around them.
"""

# Step 1: Preprocessing the text--NLP
tokenizer = Tokenizer(char_level=True)  # Tokenize at the character level
tokenizer.fit_on_texts(text)
char_index = tokenizer.word_index
index_char = tokenizer.index_word
vocab_size = len(char_index) + 1

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(text)

# Flatten the list of sequences
sequences = [item for sublist in sequences for item in sublist]

# Create input-output pairs
seq_length = 40
X, y = [], []
for i in range(len(sequences) - seq_length):
    X.append(sequences[i:i + seq_length])
    y.append(sequences[i + seq_length])

X = np.array(X)
y = to_categorical(y, num_classes=vocab_size)

# Step 2: Building the LSTM model
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=50, input_length=seq_length),
    LSTM(150, return_sequences=False),
    Dense(vocab_size, activation='softmax')#Activation tanh
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Step 3: Training the model
model.fit(X, y, epochs=100, batch_size=64)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.0594 - loss: 3.2574
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.1921 - loss: 3.2400
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.1389 - loss: 3.2148
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.1350 - loss: 3.1265
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.1408 - loss: 2.9914
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.1408 - loss: 2.9842
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1467 - loss: 2.9243
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1486 - loss: 2.9270
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1525 - loss: 2.8889
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1584 - loss: 2.8982
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1829 - loss: 2.9299
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1088 - loss: 2.9059
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1166 - loss: 2.9108
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1322 - loss: 2.8898
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.1790 - loss: 2.9080
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1291 - loss: 2.9253
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.1467 - loss: 2.9060
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1252 - loss: 2.9234
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1584 - loss: 2.8551
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1408 - loss: 2.8863
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1525 - loss: 2.8527
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1369 - loss: 2.8847
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1447 - loss: 2.8932
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1389 - loss: 2.8510
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1698 - loss: 2.8274
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.2295 - loss: 2.8483
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2273 - loss: 2.8350
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1389 - loss: 2.8279
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1408 - loss: 2.8161
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.1408 - loss: 2.8088
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.1447 - loss: 2.8082
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1447 - loss: 2.8304
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1503 - loss: 2.7947
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.2250 - loss: 2.7807
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.1882 - loss: 2.7349
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1762 - loss: 2.7310
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2281 - loss: 2.6641
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2158 - loss: 2.6999
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1852 - loss: 2.6716
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2390 - loss: 2.6130
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.2705 - loss: 2.5907
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3015 - loss: 2.5565
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.2780 - loss: 2.5432
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.2819 - loss: 2.4743
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.2875 - loss: 2.4649
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.2984 - loss: 2.4394
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.3095 - loss: 2.4079
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3424 - loss: 2.3364
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.3079 - loss: 2.2950
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3042 - loss: 2.2927
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.3154 - loss: 2.2412
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.3346 - loss: 2.1521
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.3098 - loss: 2.1601
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3282 - loss: 2.1989
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3516 - loss: 2.0055
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.3687 - loss: 2.0047
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4083 - loss: 1.9991
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4024 - loss: 1.9557
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4102 - loss: 1.9091
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4532 - loss: 1.8633
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3999 - loss: 1.8728
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4272 - loss: 1.8090
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4306 - loss: 1.7847
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4029 - loss: 1.7903
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4534 - loss: 1.6649
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4548 - loss: 1.6474
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4699 - loss: 1.6197
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4654 - loss: 1.6189
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4978 - loss: 1.5322
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5376 - loss: 1.5045
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5382 - loss: 1.4347
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5962 - loss: 1.4236
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5904 - loss: 1.3710
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6012 - loss: 1.3789
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6297 - loss: 1.3055
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6813 - loss: 1.2298
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6453 - loss: 1.2558
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6280 - loss: 1.1850
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6617 - loss: 1.1518
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6885 - loss: 1.1278
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6955 - loss: 1.1079
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7161 - loss: 1.0716
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7669 - loss: 1.0380
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7713 - loss: 0.9667
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7518 - loss: 0.9975
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7591 - loss: 0.9835
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8068 - loss: 0.9007
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8424 - loss: 0.8482
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8173 - loss: 0.8689
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8971 - loss: 0.8010
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8837 - loss: 0.7822
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8215 - loss: 0.7695
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8514 - loss: 0.7408
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9161 - loss: 0.6713
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9119 - loss: 0.7092
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9417 - loss: 0.6591
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9269 - loss: 0.6365
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9102 - loss: 0.6074
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9136 - loss: 0.6111
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9342 - loss: 0.6086

# %%
def generate_text(seed_text, num_chars):
    for _ in range(num_chars):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=seq_length, truncating='pre')
        predicted_probs = model.predict(token_list, verbose=0)
        predicted_char_index = np.argmax(predicted_probs)
        predicted_char = index_char[predicted_char_index]
        seed_text += predicted_char
    return seed_text

# %%
seed_text = "Once upon a time"
generated_text = generate_text(seed_text, num_chars=200)
print("Generated text:\n", generated_text)
# Out:
# Generated text:
#  Once upon a timed ilage lareround by bh he arere fihe the the vilage surroundd by bush geren ferestthe the village surroundd by bush gree ferestthe the village surredd by bsh he aree forestthe the villagers lived in
